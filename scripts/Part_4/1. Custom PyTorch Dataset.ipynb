# %%
import torch
from torch.utils.data import Dataset
from torchvision.io import decode_image
import os
import pandas as pd


class MyCustomDataset(Dataset):

  def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
    '''Custom logic to initialise the dataset.'''

    super(MyCustomDataset, self).__init__()
    self.img_dir = img_dir
    self.labels = pd.read_csv(csv_file_path)

    self.target_transform = target_transform
    self.transform = transform

  def __getitem__(self, index):
    '''Retrieve a sample from the dataset from a given key.'''

    img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
    image = decode_image(img_path)
    label = self.img_labels.iloc[idx, 1]
    if self.transform:
        image = self.transform(image)
    if self.target_transform:
        label = self.target_transform(label)
    return image, label

  def __len__(self):
    '''Returns the length of the dataset (# of samples).'''

    return len(self.data)

# %%
my_dataset = MyCustomDataset('my_file.csv')
